# %%
import sys
import os
import pandas as pd
#Ensure Python can find the Code directory
sys.path.append(os.path.abspath(".."))

import utils

# %%
#Use functions and packages
df = utils.load_data()
df.sample(20)
# Out:
#         activity_year  census_tract        derived_race  action_taken  \
# 63282            2023  2.705301e+10               White             1
# 40032            2023  2.712304e+10               White             1
# 71233            2023  2.700305e+10  Race Not Available             4
# 53985            2023  2.705303e+10               White             1
# 38298            2023  2.714103e+10               White             1
# 93049            2023  2.713700e+10               White             1
# 4327             2023  2.705302e+10               Asian             1
# 14114            2023  2.702900e+10               White             1
# 96533            2023  2.705303e+10               Joint             4
# 33886            2023  2.705303e+10               White             1
# 73050            2023  2.703706e+10  Race Not Available             6
# 13044            2023  2.705107e+10               White             4
# 16271            2023  2.716307e+10               Asian             1
# 28668            2023  2.704596e+10               White             1
# 54306            2023  2.701909e+10               White             1
# 14825            2023  2.703706e+10               White             3
# 98000            2023  2.703706e+10               White             1
# 84821            2023  2.710900e+10               White             1
# 100880           2023  2.705303e+10               White             1
# 8876             2023  2.704145e+10               White             1
#
#         loan_amount  property_value  income  interest_rate  \
# 63282      375000.0        425000.0   154.0          7.490
# 40032       15000.0        275000.0    70.0            NaN
# 71233      455000.0             NaN   104.0            NaN
# 53985      385000.0        405000.0   102.0          6.250
# 38298      325000.0        385000.0   120.0          5.250
# 93049      195000.0        215000.0    84.0          6.000
# 4327       295000.0        295000.0    89.0          5.999
# 14114      315000.0        335000.0    90.0          7.125
# 96533      315000.0             NaN   236.0            NaN
# 33886      195000.0        245000.0   109.0          5.999
# 73050      345000.0        435000.0     NaN          7.125
# 13044       85000.0             NaN    72.0            NaN
# 16271      445000.0        525000.0   106.0          5.990
# 28668      165000.0        175000.0    56.0          6.500
# 54306      175000.0        195000.0    81.0          6.375
# 14825      205000.0        195000.0    49.0            NaN
# 98000      425000.0        505000.0    83.0          5.625
# 84821       15000.0        235000.0    51.0          0.000
# 100880     305000.0        345000.0   129.0          6.125
# 8876       145000.0        155000.0    42.0          5.990
#
#         tract_minority_population_percent  tract_to_msa_income_percentage  \
# 63282                               13.76                          149.42
# 40032                               43.24                          104.09
# 71233                               24.28                          116.26
# 53985                               29.16                           80.69
# 38298                                6.67                          114.02
# 93049                               18.80                           57.84
# 4327                                25.44                           94.58
# 14114                               10.17                           99.93
# 96533                                9.79                          139.24
# 33886                               19.17                          157.94
# 73050                               10.92                          154.89
# 13044                                6.16                           94.19
# 16271                               28.48                          139.88
# 28668                                4.30                           73.91
# 54306                               15.91                          121.42
# 14825                               29.78                          104.59
# 98000                               20.12                           90.16
# 84821                               33.83                           55.83
# 100880                               9.08                          146.65
# 8876                                 8.59                          110.22
#
#         denial_reason-1  covenant_count  was_approved  covenant_density
# 63282                10           875.0          True  Very High (>200)
# 40032                10             0.0          True               NaN
# 71233                10             0.0         False               NaN
# 53985                10             0.0          True               NaN
# 38298                10             0.0          True               NaN
# 93049                10             0.0          True               NaN
# 4327                 10           362.0          True  Very High (>200)
# 14114                10             0.0          True               NaN
# 96533                10             0.0         False               NaN
# 33886                10             0.0          True               NaN
# 73050                10             0.0         False               NaN
# 13044                10             0.0         False               NaN
# 16271                10             0.0          True               NaN
# 28668                10             0.0          True               NaN
# 54306                10             0.0          True               NaN
# 14825                 1             0.0         False               NaN
# 98000                10             0.0          True               NaN
# 84821                10             0.0          True               NaN
# 100880               10             0.0          True               NaN
# 8876                 10             0.0          True               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100931 entries, 0 to 100930
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   activity_year                      100931 non-null  int64
#  1   census_tract                       99915 non-null   float64
#  2   derived_race                       100931 non-null  object
#  3   action_taken                       100931 non-null  int64
#  4   loan_amount                        100931 non-null  float64
#  5   property_value                     83491 non-null   float64
#  6   income                             88200 non-null   float64
#  7   interest_rate                      78125 non-null   float64
#  8   tract_minority_population_percent  100931 non-null  float64
#  9   tract_to_msa_income_percentage     100931 non-null  float64
#  10  denial_reason-1                    100931 non-null  int64
#  11  covenant_count                     100931 non-null  float64
#  12  was_approved                       100931 non-null  bool
#  13  covenant_density                   11169 non-null   object
# dtypes: bool(1), float64(8), int64(3), object(2)
# memory usage: 10.1+ MB

# %%
# create the category "None" for entries with no covenants

df['covenant_density'].fillna('None', inplace=True)
# Out:
# /var/folders/mj/_5nwhhkd5cjbp6mcqnk7hh540000gn/T/ipykernel_90993/3401214430.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['covenant_density'].fillna('None', inplace=True)

# %%
# calculate approval rate by race

df.groupby('derived_race')['was_approved'].mean().reset_index(name='approval_rate')
# Out:
#                                 derived_race  approval_rate
# 0                   2 or more minority races       0.659259
# 1           American Indian or Alaska Native       0.622003
# 2                                      Asian       0.707705
# 3                  Black or African American       0.604155
# 4                        Free Form Text Only       0.800000
# 5                                      Joint       0.744129
# 6  Native Hawaiian or Other Pacific Islander       0.566372
# 7                         Race Not Available       0.405725
# 8                                      White       0.756063

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_filtered = df[df['derived_race'] != 'Free Form Text Only']

# calculate and sort approval rates
approval_summary = df_filtered.groupby('derived_race')['was_approved'].mean().reset_index(name='approval_rate')

approval_summary = approval_summary.sort_values(by='approval_rate', ascending=True)

plt.figure(figsize=(10,6))
sns.barplot(data=approval_summary, y='derived_race', x='approval_rate', palette='pastel')

plt.title('Loan Approval Rate by Race')
plt.ylabel('Race')
plt.xlabel('Approval Rate')
plt.xlim(0,1)
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '{:.0%}'.format(x)))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/mj/_5nwhhkd5cjbp6mcqnk7hh540000gn/T/ipykernel_90993/4072856037.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=approval_summary, y='derived_race', x='approval_rate', palette='pastel')

# %%
df['is_covenanted'] = df['covenant_count'].fillna(0) > 0

# %%
approval_by_covenant = df.groupby('is_covenanted')['was_approved'].mean().reset_index(name='approval_rate')
print(approval_by_covenant)
# Out:
#    is_covenanted  approval_rate
# 0          False           0.66
# 1           True           0.67

# %%
df['loan_amount'].describe()
# Out:
# count      100,931.00
# mean       311,005.98
# std        761,708.83
# min          5,000.00
# 25%        175,000.00
# 50%        265,000.00
# 75%        365,000.00
# max     57,005,000.00
# Name: loan_amount, dtype: float64

# %%
df_filtered = df[df['loan_amount'] < 750000]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df_filtered, x='covenant_density', y='loan_amount')

plt.title('Loan Amount vs. Covenant Density')
plt.xlabel('Covenant Density')
plt.ylabel('Loan Amount')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df_filtered, x='covenant_density', y='interest_rate')

plt.title('Interest Rate vs. Covenant Density')
plt.xlabel('Covenant Density')
plt.ylabel('Interest Rate')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Calculate approval rate by covenant density
approval_rates = df.groupby('covenant_density')['was_approved'].mean().reset_index()

# Create the bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x='covenant_density', y='was_approved', data=approval_rates, palette='viridis')

# Add title and labels
plt.title('Loan Approval Rate by Covenant Density')
plt.xlabel('Covenant Density')
plt.ylabel('Approval Rate')
plt.ylim(0, 1)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/mj/_5nwhhkd5cjbp6mcqnk7hh540000gn/T/ipykernel_90993/3599252400.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='covenant_density', y='was_approved', data=approval_rates, palette='viridis')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df_filtered, x='covenant_density', y='tract_minority_population_percent')

plt.title('Minority Population Percentage vs. Covenant Density')
plt.xlabel('Covenant Density')
plt.ylabel('Minority Percentage')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns


# Boxplot to visualize distribution
plt.figure(figsize=(8, 6))
sns.boxplot(x='covenant_density', y='tract_minority_population_percent', data=df, palette='viridis')
plt.title('Minority Population Percentage by Covenant Density')
plt.xlabel('Covenant Density')
plt.ylabel('Minority Population Percentage')
plt.show()

# ANOVA
model = ols('tract_minority_population_percent ~ C(covenant_density)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
# /var/folders/mj/_5nwhhkd5cjbp6mcqnk7hh540000gn/T/ipykernel_90993/1787416734.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='covenant_density', y='tract_minority_population_percent', data=df, palette='viridis')
#                            sum_sq         df      F  PR(>F)
# C(covenant_density)  1,101,351.92       4.00 955.55    0.00
# Residual            29,081,381.46 100,926.00    NaN     NaN

# %%
import statsmodels.stats.multicomp as mc

# Post-hoc test
comp = mc.MultiComparison(df['tract_minority_population_percent'], df['covenant_density'])
post_hoc_res = comp.tukeyhsd()
print(post_hoc_res)
# Out:
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================
#      group1          group2      meandiff p-adj   lower    upper   reject
# -------------------------------------------------------------------------
#  High (101-200)       Low (1-50)  13.3508    0.0  12.0396  14.6619   True
#  High (101-200)  Medium (51-100)   2.7787    0.0   1.2114    4.346   True
#  High (101-200)             None  -2.2096    0.0  -3.3367  -1.0825   True
#  High (101-200) Very High (>200)   1.2806 0.0873  -0.1084   2.6697  False
#      Low (1-50)  Medium (51-100) -10.5721    0.0 -11.8692  -9.2749   True
#      Low (1-50)             None -15.5604    0.0  -16.265 -14.8558   True
#      Low (1-50) Very High (>200) -12.0701    0.0  -13.145 -10.9952   True
# Medium (51-100)             None  -4.9883    0.0  -6.0991  -3.8775   True
# Medium (51-100) Very High (>200)  -1.4981 0.0248  -2.8738  -0.1223   True
#            None Very High (>200)   3.4903    0.0   2.6496   4.3309   True
# -------------------------------------------------------------------------

# %%
# Calculate approval rates
approval_rates = df.groupby('covenant_density')['was_approved'].mean().reset_index()
approval_rates.rename(columns={'was_approved': 'approval_rate'}, inplace=True)

print(approval_rates)
# Out:
#    covenant_density  approval_rate
# 0    High (101-200)           0.69
# 1        Low (1-50)           0.66
# 2   Medium (51-100)           0.67
# 3              None           0.66
# 4  Very High (>200)           0.67

# %%
import scipy.stats as stats

# Create a contingency table
contingency_table = pd.crosstab(df['covenant_density'], df['was_approved'])

# Perform Chi-Square Test of Independence
chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p}")
# Out:
# Chi-Square Statistic: 7.912700491338773
# P-Value: 0.09482894272023591

# %%
# ANOVA
model = ols('loan_amount ~ C(covenant_density)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                                        sum_sq         df     F  PR(>F)
# C(covenant_density)     77,517,888,345,992.27       4.00 33.44    0.00
# Residual            58,482,101,844,039,256.00 100,926.00   NaN     NaN

# %%
# Post-hoc test
comp = mc.MultiComparison(df['loan_amount'], df['covenant_density'])
post_hoc_res = comp.tukeyhsd()
print(post_hoc_res)
# Out:
#                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================================
#      group1          group2        meandiff   p-adj     lower        upper    reject
# ------------------------------------------------------------------------------------
#  High (101-200)       Low (1-50)  -76757.5157 0.0034  -135554.204 -17960.8275   True
#  High (101-200)  Medium (51-100)    -684.1304    1.0  -70968.6103  69600.3495  False
#  High (101-200)             None -119155.2734    0.0 -169699.9872 -68610.5596   True
#  High (101-200) Very High (>200)  -24420.6044 0.8223  -86709.0491  37867.8404  False
#      Low (1-50)  Medium (51-100)   76073.3853 0.0033   17905.6152 134241.1555   True
#      Low (1-50)             None  -42397.7577 0.0023  -73994.4262 -10801.0892   True
#      Low (1-50) Very High (>200)   52336.9114 0.0255    4134.9226 100538.9001   True
# Medium (51-100)             None  -118471.143    0.0 -168282.8588 -68659.4272   True
# Medium (51-100) Very High (>200)   -23736.474 0.8322  -85431.6058  37958.6579  False
#            None Very High (>200)    94734.669    0.0   57036.5356 132432.8025   True
# ------------------------------------------------------------------------------------
